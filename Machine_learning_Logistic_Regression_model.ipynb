# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Insurance = pd.read_csv("/content/drive/MyDrive/insurance_data 1 (1).csv")
Insurance
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
#EXPLORATORY DATA ANALYSIS

# %%
Insurance.shape
# Out:
# (27, 2)

# %%
Insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 560.0 bytes

# %%
Insurance.isna().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
Insurance.describe()
# Out:
#              age  bought_insurance
# count  27.000000         27.000000
# mean   39.666667          0.518519
# std    15.745573          0.509175
# min    18.000000          0.000000
# 25%    25.000000          0.000000
# 50%    45.000000          1.000000
# 75%    54.500000          1.000000
# max    62.000000          1.000000

# %%
Insurance.duplicated().sum()
# Out:
# 1

# %%
Insurance.dtypes
# Out:
# age                 int64
# bought_insurance    int64
# dtype: object

# %%
Insurance.columns
# Out:
# Index(['age', 'bought_insurance'], dtype='object')

# %%
plt.scatter(Insurance.age,Insurance.bought_insurance)

# %%
Insurance
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
X_train,X_test,y_train, y_test = train_test_split(Insurance[["age"]],Insurance.bought_insurance, train_size = 0.7)
X_train,X_test,y_train, y_test
# Out:
# (    age
#  6    55
#  5    56
#  0    22
#  4    46
#  26   23
#  21   26
#  14   49
#  19   18
#  13   29
#  3    52
#  8    62
#  18   19
#  25   54
#  1    25
#  11   28
#  16   25
#  23   45
#  7    60,
#      age
#  10   18
#  24   50
#  22   40
#  12   27
#  9    61
#  17   58
#  2    47
#  20   21
#  15   55,
#  6     0
#  5     1
#  0     0
#  4     1
#  26    0
#  21    0
#  14    1
#  19    0
#  13    0
#  3     0
#  8     1
#  18    0
#  25    1
#  1     0
#  11    0
#  16    1
#  23    1
#  7     1
#  Name: bought_insurance, dtype: int64,
#  10    0
#  24    1
#  22    1
#  12    0
#  9     1
#  17    1
#  2     1
#  20    0
#  15    1
#  Name: bought_insurance, dtype: int64)

# %%
X_test
# Out:
#     age
# 10   18
# 24   50
# 22   40
# 12   27
# 9    61
# 17   58
# 2    47
# 20   21
# 15   55

# %%
X_train
# Out:
#     age
# 1    25
# 21   26
# 18   19
# 4    46
# 23   45
# 6    55
# 19   18
# 24   50
# 10   18
# 16   25
# 13   29
# 14   49
# 2    47
# 22   40
# 12   27
# 9    61
# 26   23
# 8    62
# 20   21
# 15   55
# 25   54

# %%
y_test
# Out:
# 0     0
# 7     1
# 11    0
# 3     0
# 5     1
# 17    1
# Name: bought_insurance, dtype: int64

# %%
len(X_train)
# Out:
# 18

# %%
len(X_test)
# Out:
# 9

# %%
len(y_test)
# Out:
# 9

# %%
len(y_train)
# Out:
# 18

# %%
model = LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_train
# Out:
#     age
# 6    55
# 5    56
# 0    22
# 4    46
# 26   23
# 21   26
# 14   49
# 19   18
# 13   29
# 3    52
# 8    62
# 18   19
# 25   54
# 1    25
# 11   28
# 16   25
# 23   45
# 7    60

# %%
y_train
# Out:
# 6     0
# 5     1
# 0     0
# 4     1
# 26    0
# 21    0
# 14    1
# 19    0
# 13    0
# 3     0
# 8     1
# 18    0
# 25    1
# 1     0
# 11    0
# 16    1
# 23    1
# 7     1
# Name: bought_insurance, dtype: int64

# %%
X_test
# Out:
#     age
# 10   18
# 24   50
# 22   40
# 12   27
# 9    61
# 17   58
# 2    47
# 20   21
# 15   55

# %%
y_test
# Out:
# 10    0
# 24    1
# 22    1
# 12    0
# 9     1
# 17    1
# 2     1
# 20    0
# 15    1
# Name: bought_insurance, dtype: int64

# %%
X_test
# Out:
#     age
# 10   18
# 24   50
# 22   40
# 12   27
# 9    61
# 17   58
# 2    47
# 20   21
# 15   55

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0, 0, 1, 1, 1, 0, 1])
