# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
from sklearn import linear_model #sklearn
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv("/content/drive/MyDrive/homeprices - homeprices (1).csv")
df
# Out:
#     area   price
# 0   2600  550000
# 1   3000  565000
# 2   3200  610000
# 3   3600  680000
# 4   4000  725000
# 5   2600  585000
# 6   2800  615000
# 7   3300  650000
# 8   3600  710000
# 9   2600  575000
# 10  2900  600000
# 11  3100  620000
# 12  3600  695000

# %% [markdown]
# **Exploratory Data analysis**

# %%
#checking for the shape of the data
df.shape
# Out:
# (13, 2)

# %%
#getting the description of the data
df.describe()
# Out:
#               area          price
# count    13.000000      13.000000
# mean   3146.153846  629230.769231
# std     453.900475   57621.109914
# min    2600.000000  550000.000000
# 25%    2800.000000  585000.000000
# 50%    3100.000000  615000.000000
# 75%    3600.000000  680000.000000
# max    4000.000000  725000.000000

# %%
#getting the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    13 non-null     int64
#  1   price   13 non-null     int64
# dtypes: int64(2)
# memory usage: 336.0 bytes

# %%
#checking for mnissing value
df.isna().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
df.head(3)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000

# %%
plt.scatter(df.area,df.price,color = "red", marker = "+")
plt.xlabel ("Area")
plt.ylabel ("Price")
plt.title ("Area price chat")
# Out:
# Text(0.5, 1.0, 'Area price chat')

# %%
df.head(3)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000

# %%
#split columns (independent columns
#(area) and dependent(price))

# %%
#The independent variable
new_df = df.drop("price", axis = "columns")
new_df
# Out:
#     area
# 0   2600
# 1   3000
# 2   3200
# 3   3600
# 4   4000
# 5   2600
# 6   2800
# 7   3300
# 8   3600
# 9   2600
# 10  2900
# 11  3100
# 12  3600

# %%
df.head(2)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000

# %%
#The dependent variable
price = df.price
price
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
new_df
# Out:
#     area
# 0   2600
# 1   3000
# 2   3200
# 3   3600
# 4   4000
# 5   2600
# 6   2800
# 7   3300
# 8   3600
# 9   2600
# 10  2900
# 11  3100
# 12  3600

# %%
price
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
reg = linear_model.LinearRegression()
reg.fit (new_df,price)

# %%
#predict price of house with 3300 sqr ft

# %%
reg.predict([[3330]])
# Out:
# array([650978.84256378])

# %%
reg.coef_
# Out:
# array([118.29495955])

# %%
reg.intercept_
# Out:
# 257056.627255756

# %%
#Y =M* X + B ( M is the coeffiecent and b is the intercept)
3300*118.29495955+257056.627255756
# Out:
# 647429.9937707561

# %%
#predict price of a home with area = 5000 sqr ft
#predict price of a home with area = 60000 sqr ft
#predict price of a home with area = 7000 sqr ft
#predict price of a home with area = 10000 sqr ft

# %%
reg.predict([[5000]])
# Out:
# array([848531.42501556])

# %%
reg.predict([[60000]])
# Out:
# array([7354754.20037337])

# %%
reg.predict([[7000 ]])
# Out:
# array([1085121.34411948])

# %%
reg.predict([[10000 ]])
# Out:
# array([1440006.22277536])
